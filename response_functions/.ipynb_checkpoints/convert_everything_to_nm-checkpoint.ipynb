# %%
% matplotlib inline
import numpy as np
import matplotlib.pylab as plt
import seaborn as sb

from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler()

# %%
transmission = {'Kp' : '../response_functions_original/kepler_response.txt',
                'S1' : '../response_functions_original/spitzer_1.txt',
                'S2' : '../response_functions_original/spitzer_2.txt',
                'S3' : '../response_functions_original/spitzer_3.txt',
                'S4' : '../response_functions_original/spitzer_4.txt',
                'u'  : '../response_functions_original/Stroemgren_u.txt',
                'v'  : '../response_functions_original/Stroemgren_v.txt',
                'b'  : '../response_functions_original/Stroemgren_b.txt',
                'y'  : '../response_functions_original/Stroemgren_y.txt',
                'U'  : '../response_functions_original/Bessel_U-1.txt',
                'V'  : '../response_functions_original/Bessel_V-1.txt',
                'B'  : '../response_functions_original/Bessel_B-1.txt',
                'R'  : '../response_functions_original/Bessel_R-1.txt',
                'I'  : '../response_functions_original/Bessel_I-1.txt',
                'J'  : '../response_functions_original/2MASS_Jband.dat',
                'H'  : '../response_functions_original/2MASS_Hband.dat',
                'K'  : '../response_functions_original/2MASS_Kband.dat',
                'u_' : '../response_functions_original/SDSS_u.dat',
                'g_' : '../response_functions_original/SDSS_g.dat',
                'r_' : '../response_functions_original/SDSS_r.dat',
                'i_' : '../response_functions_original/SDSS_i.dat',
                'z_' : '../response_functions_original/SDSS_z.dat',
                'vT' : '../response_functions_original/v_tycho.dat',
                'bT' : '../response_functions_original/b_tycho.dat',
                'W1' : '../response_functions_original/WISE_1.txt',
                'W2' : '../response_functions_original/WISE_2.txt',
                'W3' : '../response_functions_original/WISE_3.txt',
                'W4' : '../response_functions_original/WISE_4.txt',
                'Cp' : '../response_functions_original/cheops.txt'
               }

# %%
outputs =      {'Kp' : '../response_functions/kepler_response.txt',
                'S1' : '../response_functions/spitzer_1.txt',
                'S2' : '../response_functions/spitzer_2.txt',
                'S3' : '../response_functions/spitzer_3.txt',
                'S4' : '../response_functions/spitzer_4.txt',
                'u'  : '../response_functions/Stroemgren_u.txt',
                'v'  : '../response_functions/Stroemgren_v.txt',
                'b'  : '../response_functions/Stroemgren_b.txt',
                'y'  : '../response_functions/Stroemgren_y.txt',
                'U'  : '../response_functions/Bessel_U-1.txt',
                'V'  : '../response_functions/Bessel_V-1.txt',
                'B'  : '../response_functions/Bessel_B-1.txt',
                'R'  : '../response_functions/Bessel_R-1.txt',
                'I'  : '../response_functions/Bessel_I-1.txt',
                'J'  : '../response_functions/2MASS_Jband.txt',
                'H'  : '../response_functions/2MASS_Hband.txt',
                'K'  : '../response_functions/2MASS_Kband.txt',
                'u_' : '../response_functions/SDSS_u.txt',
                'g_' : '../response_functions/SDSS_g.txt',
                'r_' : '../response_functions/SDSS_r.txt',
                'i_' : '../response_functions/SDSS_i.txt',
                'z_' : '../response_functions/SDSS_z.txt',
                'vT' : '../response_functions/v_tycho.txt',
                'bT' : '../response_functions/b_tycho.txt',
                'W1' : '../response_functions/WISE_1.txt',
                'W2' : '../response_functions/WISE_2.txt',
                'W3' : '../response_functions/WISE_3.txt',
                'W4' : '../response_functions/WISE_4.txt',
                'Cp' : '../response_functions/cheops.txt'
               }

# %%
Kp = np.loadtxt(transmission['Kp']) # tick
np.savetxt(outputs['Kp'],Kp, fmt='%6.2f %8.6f')

S1 = np.loadtxt(transmission['S1'])
S1[:,0] = S1[:,0]*1000
np.savetxt(outputs['S1'],S1, fmt='%6.2f %8.6f')

S2 = np.loadtxt(transmission['S2'])
S2[:,0] = S2[:,0]*1000
np.savetxt(outputs['S2'],S2, fmt='%6.2f %8.6f')

S3 = np.loadtxt(transmission['S3'])
S3[:,0] = S3[:,0]*1000
np.savetxt(outputs['S3'],S3, fmt='%6.2f %8.6f')

S4 = np.loadtxt(transmission['S4'])
S4[:,0] = S4[:,0]*1000
np.savetxt(outputs['S4'],S4, fmt='%6.2f %8.6f')

u = np.loadtxt(transmission['u']) # tick
np.savetxt(outputs['u'],u, fmt='%6.2f %8.6f')

v = np.loadtxt(transmission['v']) # tick
np.savetxt(outputs['v'],v, fmt='%6.2f %8.6f')

b = np.loadtxt(transmission['b']) # tick
np.savetxt(outputs['b'],b, fmt='%6.2f %8.6f')

y = np.loadtxt(transmission['y']) # tick
np.savetxt(outputs['y'],y, fmt='%6.2f %8.6f')

U = np.loadtxt(transmission['U']) # tick
np.savetxt(outputs['U'],U, fmt='%6.2f %8.6f')

V = np.loadtxt(transmission['V']) # tick
np.savetxt(outputs['V'],V, fmt='%6.2f %8.6f')

B = np.loadtxt(transmission['B']) # tick
np.savetxt(outputs['B'],B, fmt='%6.2f %8.6f')

R = np.loadtxt(transmission['R']) # tick
np.savetxt(outputs['R'],R, fmt='%6.2f %8.6f')

I = np.loadtxt(transmission['I']) # tick
np.savetxt(outputs['I'],I, fmt='%6.2f %8.6f')

J = np.loadtxt(transmission['J'])
J[:,0] = J[:,0]*1000
np.savetxt(outputs['J'],J, fmt='%6.2f %8.6f')

H = np.loadtxt(transmission['H'])
H[:,0] = H[:,0]*1000
np.savetxt(outputs['H'],H, fmt='%6.2f %8.6f')

K = np.loadtxt(transmission['K'])
K[:,0] = K[:,0]*1000
np.savetxt(outputs['K'],K, fmt='%6.2f %8.6f')

u_ = np.loadtxt(transmission['u_'])
u_[:,0] = u_[:,0]/10
np.savetxt(outputs['u_'],u_[:,:2], fmt='%6.2f %8.6f')

g_ = np.loadtxt(transmission['g_'])
g_[:,0] = g_[:,0]/10
np.savetxt(outputs['g_'],g_[:,:2], fmt='%6.2f %8.6f')

r_ = np.loadtxt(transmission['r_'])
r_[:,0] = r_[:,0]/10
np.savetxt(outputs['r_'],r_[:,:2], fmt='%6.2f %8.6f')

i_ = np.loadtxt(transmission['i_'])
i_[:,0] = i_[:,0]/10
np.savetxt(outputs['i_'],i_[:,:2], fmt='%6.2f %8.6f')

z_ = np.loadtxt(transmission['z_'])
z_[:,0] = z_[:,0]/10
np.savetxt(outputs['z_'],z_[:,:2], fmt='%6.2f %8.6f')

vT = np.loadtxt(transmission['vT'])
vT[:,0] = vT[:,0]/10
np.savetxt(outputs['vT'],vT, fmt='%6.2f %8.6f')

bT = np.loadtxt(transmission['bT'])
bT[:,0] = bT[:,0]/10
np.savetxt(outputs['bT'],bT, fmt='%6.2f %8.6f')

W1 = np.loadtxt(transmission['W1'])
W1[:,0] = W1[:,0]*1000
np.savetxt(outputs['W1'],W1[:,:2], fmt='%6.2f %8.6f')

W2 = np.loadtxt(transmission['W2'])
W2[:,0] = W2[:,0]*1000
np.savetxt(outputs['W2'],W2[:,:2], fmt='%6.2f %8.6f')

W3 = np.loadtxt(transmission['W3'])
W3[:,0] = W3[:,0]*1000
np.savetxt(outputs['W3'],W3[:,:2], fmt='%6.2f %8.6f')

W4 = np.loadtxt(transmission['W4'])
W4[:,0] = W4[:,0]*1000
np.savetxt(outputs['W4'],W4[:,:2], fmt='%6.2f %8.6f')

# %%
filters = {'Kp':Kp,
           'S1':S1,
           'S2':S2,
           'S3':S3,
           'S4':S4,
           'u':u,
           'v':v,
           'b':b,
           'y':y,
           'U':U,
           'V':V,
           'B':B,
           'R':R,
           'I':I,
           'J':J,
           'H':H,
           'K':K,
           'u_':u_,
           'g_':g_,
           'r_':r_,
           'i_':i_,
           'z_':z_,
           'vT':vT,
           'bT':bT,
           'W1':W1,
           'W2':W2,
           'W3':W3,
           'W4':W4
          }

with sb.axes_style():
    fig, axs = plt.subplots(1,1)
    for filt in filters:
        axs.plot(filters[filt][:,0],scale.fit_transform(filters[filt][:,1]),label=filt)
    #plt.setp(axs,xlim=[200,1500])
    axs.legend()

# %%
# correcting for the transmission being in reverse order...!

u = np.loadtxt(outputs['u'])
u = u[::-1,:]
np.savetxt(outputs['u'],u, fmt='%6.2f %8.6f')

v = np.loadtxt(outputs['v'])
v = v[::-1,:]
np.savetxt(outputs['v'],v, fmt='%6.2f %8.6f')

b = np.loadtxt(outputs['b'])
b = b[::-1,:]
np.savetxt(outputs['b'],b, fmt='%6.2f %8.6f')

y = np.loadtxt(outputs['y'])
y = y[::-1,:]
np.savetxt(outputs['y'],y, fmt='%6.2f %8.6f')

U = np.loadtxt(outputs['U'])
U = U[::-1,:]
np.savetxt(outputs['U'],U, fmt='%6.2f %8.6f')

V = np.loadtxt(outputs['v'])
v = v[::-1,:]
np.savetxt(outputs['v'],v, fmt='%6.2f %8.6f')

B = np.loadtxt(outputs['B'])
B = B[::-1,:]
np.savetxt(outputs['B'],B, fmt='%6.2f %8.6f')

R = np.loadtxt(outputs['R'])
R = R[::-1,:]
np.savetxt(outputs['R'],R, fmt='%6.2f %8.6f')

I = np.loadtxt(outputs['I'])
I = I[::-1,:]
np.savetxt(outputs['I'],I, fmt='%6.2f %8.6f')

# %%
v = np.loadtxt(outputs['v'])
v = v[::-1,:]
np.savetxt(outputs['v'],v, fmt='%6.2f %8.6f')

V = np.loadtxt(outputs['V'])
V = V[::-1,:]
np.savetxt(outputs['V'],V, fmt='%6.2f %8.6f')
